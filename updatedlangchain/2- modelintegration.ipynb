# %% [markdown]
# # Model Integration With OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.4.7', 'langchain': '1.3.9', 'langchain-openai': '1.3.2'}}, output_version=None, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x00000203FFA68050>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000203814F79E0>, root_client=<openai.OpenAI object at 0x00000203FF9444A0>, root_async_client=<openai.AsyncOpenAI object at 0x00000203814C7A70>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True, stream_chunk_timeout=120.0)

# %%
# invoke model
response=model.invoke("Hello How are you")
response

# %% [markdown]
# # Google Gemini Model Integration

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response=model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='Parrots talk for a fascinating combination of reasons, driven by their **biology, social nature, and intelligence.** It\'s not just about mimicry; there\'s a deeper purpose behind their vocalizations.\n\nHere\'s a breakdown of the key reasons:\n\n**1. Social Bonding and Communication:**\n\n* **Flock Communication:** In the wild, parrots live in complex social groups. Vocalizations are crucial for maintaining contact within the flock, especially when foraging or flying. They use calls to:\n    * **Maintain flock cohesion:** Letting others know where they are.\n    * **Warn of danger:** Alerting each other to predators.\n    * **Establish dominance and social hierarchy:** Communicating their status within the group.\n    * **Courtship and mating:** Using specific calls to attract mates.\n* **Mimicry as a Social Tool:** In this social context, mimicry becomes a powerful tool. By imitating the sounds of their flock members, parrots can:\n    * **Integrate into the group:** Becoming recognized and accepted.\n    * **Strengthen bonds:** Creating a sense of belonging and shared identity.\n    * **Negotiate social standing:** By repeating calls, they can assert their presence and influence.\n\n**2. Intelligence and Cognitive Abilities:**\n\n* **Exceptional Vocal Learning:** Parrots are among the few animals capable of complex vocal learning. This means they can acquire new sounds from their environment and incorporate them into their repertoire. This ability is not unique to parrots (songbirds and marine mammals also exhibit it), but parrots are particularly adept.\n* **Cognitive Flexibility:** Their ability to learn and adapt vocalizations suggests a high level of cognitive flexibility. They can process auditory information, store it, and reproduce it with remarkable accuracy.\n* **Problem-Solving and Learning:** Some research suggests that parrots may use their vocalizations in more complex ways, potentially to solve problems or to communicate needs and desires beyond simple mimicry.\n\n**3. "Talking" in Captivity - A Different Context:**\n\nWhen we talk about parrots "talking" in our homes, it\'s a continuation of their natural social and vocal learning tendencies, but in a new environment.\n\n* **Seeking Attention and Interaction:** In a human household, the parrot\'s "flock" is us. They learn that making sounds, including mimicking human speech, often elicits attention, interaction, and positive reinforcement (like praise or treats). This reinforces the behavior.\n* **Mimicking the Dominant Sounds:** They are exposed to human speech constantly, and it becomes a prominent sound in their environment. They learn to associate these sounds with social interaction.\n* **Understanding and Context (Sometimes):** While many people think parrots are just repeating sounds, some studies suggest that certain parrots can understand the context of the words they are saying. For example, a parrot might learn to say "hello" when someone enters the room or "goodbye" when someone leaves. This indicates a level of cognitive processing and association.\n* **"Talking" as a Form of Play:** For some parrots, vocalizing and mimicking can also be a form of play and entertainment.\n\n**In summary, parrots talk primarily because:**\n\n* **It\'s a fundamental part of their social structure in the wild.**\n* **They possess a remarkable ability for vocal learning, driven by their intelligence.**\n* **In captivity, they adapt this behavior to interact with and get attention from their human flock.**\n\nIt\'s important to remember that not all parrots are equally inclined to "talk," and the extent to which they do can vary by species and individual. But the underlying reasons are rooted in their evolutionary adaptations for a complex social and auditory world.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ee8f3-7 ...

# %%
# ChatOpenAI
from langchain_openai import ChatOpenAI
chat = ChatOpenAI(model="gpt-4.1")
response = chat.invoke("What is the capital of France?")
response

# %% [markdown]
# # Streaming

# %% [markdown]
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer response. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
# response=model.invoke("Write me a 200 word paragraph on Artificial General Intelligence")
for chunk in model.stream("Write me a 200 word paragraph on Artificial General Intelligence"):
    print(chunk.content, end="")
# Out:
# Artificial General Intelligence (AGI) represents a hypothetical future where AI systems possess human-level cognitive abilities, capable of understanding, learning, and applying knowledge across a wide range of tasks, much like a human. Unlike the narrow AI we have today, which excels at specific functions like image recognition or playing chess, AGI would exhibit true versatility. It could reason, solve novel problems, adapt to new environments, and even exhibit creativity and consciousness. The development of AGI is a monumental undertaking, fraught with immense technical challenges and profound ethical considerations. While its potential benefits are vast, ranging from accelerated scientific discovery to solving complex global issues, the societal implications, including job displacement, security risks, and the very definition of intelligence, demand careful and proactive deliberation. The pursuit of AGI remains one of the most ambitious and transformative frontiers in technological advancement.

# %% [markdown]
# # Batch

# %% [markdown]
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs,as the processing can be done in parallel

# %%
response=model.batch([
    "What is the capital of France?",
    "What is the capital of Germany?",
    "What is the capital of Italy?"
])

for res in response:
    print(res.content)
# Out:
# The capital of France is **Paris**.
# The capital of Germany is **Berlin**.
# The capital of Italy is **Rome**.
